# %% [markdown]
# # PyMinHash example notebook

# %% [markdown]
# This example notebook shows how to use PyMinHash to find matches of strings.

# %% [markdown]
# First, import Pandas and fix some settings.

# %%
# %config Completer.use_jedi = False

import pandas as pd

pd.set_option('display.max_columns', 100)
pd.set_option('display.max_row', 500)
pd.set_option('display.max_colwidth', 200)

# %% [markdown]
# PyMinHash comes with a toy dataset containing various name and address combinations of Stoxx50 companies.

# %%
from pyminhash.datasets import load_data
df = load_data()
df.head()
# Out:
#                                                            name
# 0                 adidas ag adi dassler strasse 1 91074 germany
# 1          adidas ag adi dassler strasse 1 91074 herzogenaurach
# 2  adidas ag adi dassler strasse 1 91074 herzogenaurach germany
# 3                          airbus se 2333 cs leiden netherlands
# 4                                 airbus se 2333 cs netherlands

# %% [markdown]
# We're going to match various representations that belong to the same company. For this, we import create a `MinHash` object and tell it to use 10 hash tables. More hash tables means more accurate Jaccard similarity calculation but also requires more time and memory.

# %%
from pyminhash.pyminhash import MinHash
myHasher = MinHash(n_hash_tables=10)

# %% [markdown]
# The `fit_predict` method needs the dataframe and the name of the column to which minhashing should be applied. The result is a dataframe containing all pairs that have a non-zero Jaccard similarity:

# %%
result = myHasher.fit_predict(df, 'name')
result.head()
# Out:
#      row_number_1  row_number_2  \
# 632            23            24
# 2               1             2
# 204            10            11
# 271            74            75
# 623            20            22
#
#                                                            name_1  \
# 632                                   banco santander  s a  28660
# 2            adidas ag adi dassler strasse 1 91074 herzogenaurach
# 204  amadeus it group  s a  salvador de madariaga  1 28027 madrid
# 271                        kering sa 40 rue de sevres 75007 paris
# 623      banco bilbao vizcaya argentaria  s a  48005 bilbao spain
#
#                                                                      name_2  \
# 632                                      banco santander  s a  28660 madrid
# 2              adidas ag adi dassler strasse 1 91074 herzogenaurach germany
# 204      amadeus it group  s a  salvador de madariaga  1 28027 madrid spain
# 271                           kering sa 40 rue de sevres 75007 paris france
# 623  banco bilbao vizcaya argentaria  s a  plaza san nicolas  4 48005 spain
#
#      jaccard_sim
# 632          1.0
# 2            1.0
# 204          1.0
# 271          1.0
# 623          1.0

# %% [markdown]
# As one can see below, for a Jaccard similarity of 1.0, all words in the shortest string appear in the longest string. For lower Jaccard similarity values, the match is less than perfect. Note that Jaccard similarity has granularity of 1/n_hash_tables, in this example 0.1.

# %%
result.groupby('jaccard_sim').head(2)
# Out:
#      row_number_1  row_number_2  \
# 632            23            24
# 2               1             2
# 664            87            88
# 35             48            49
# 194           114           115
# 704            71            72
# 98              3             4
# 241            55            56
# 96            131           133
# 686            46            47
# 659            37            38
# 234            55            57
# 291            67           119
# 706            72            73
# 176            32           113
# 518            18           106
# 305            74           120
# 306            75           120
# 575           106           123
# 571           100           123
#
#                                                                                          name_1  \
# 632                                                                 banco santander  s a  28660
# 2                                          adidas ag adi dassler strasse 1 91074 herzogenaurach
# 664                          linde plc 10 priestley road surrey research park gu2 7xy guildford
# 35                                                    deutsche post ag platz der deutschen post
# 194                       siemens aktiengesellschaft werner von siemens strasse 1 80333 germany
# 704                                 intesa sanpaolo s p a  piazza san carlo  156 to 10121 italy
# 98                                                         airbus se 2333 cs leiden netherlands
# 241                                      engie sa 1  place samuel de champlain 92400 courbevoie
# 96                                                                  volkswagen ag 38440 germany
# 686                                                             deutsche boerse 60485 frankfurt
# 659                                                  crh plc stonemason s way 16 dublin ireland
# 234                                      engie sa 1  place samuel de champlain 92400 courbevoie
# 291  industria de diseno textil  s a  avenida de la diputacion s n arteixo 15143 a coruna spain
# 706                                 intesa sanpaolo s p a  piazza san carlo  156 to 10121 turin
# 176                     bayerische motoren werke aktiengesellschaft petuelring 130 80788 munich
# 518                                                                          axa sa 75008 paris
# 305                                                      kering sa 40 rue de sevres 75007 paris
# 306                                               kering sa 40 rue de sevres 75007 paris france
# 575                                                                         sanofi 75008 france
# 571                                                                           orange s a  paris
#
#                                                                            name_2  \
# 632                                            banco santander  s a  28660 madrid
# 2                    adidas ag adi dassler strasse 1 91074 herzogenaurach germany
# 664       linde plc 10 priestley road surrey research park gu2 7xy united kingdom
# 35                        deutsche post ag platz der deutschen post 53113 germany
# 194  siemens aktiengesellschaft werner von siemens strasse 1 80333 munich germany
# 704                   intesa sanpaolo s p a  piazza san carlo  156 to 10121 turin
# 98                                                  airbus se 2333 cs netherlands
# 241                            engie sa 1  place samuel de champlain 92400 france
# 96                                  volkswagen ag berliner ring 2 38440 wolfsburg
# 686                                                     deutsche boerse frankfurt
# 659                                           crh plc stonemason s way 16 ireland
# 234                                              engie sa 92400 courbevoie france
# 291                                     telefonica  s a  ronda de la comunicacion
# 706                                                  intesa sanpaolo s p a  turin
# 176                                     siemens aktiengesellschaft munich germany
# 518                                                           sanofi 75008 france
# 305                  telefonica  s a  ronda de la comunicacion 28050 madrid spain
# 306                  telefonica  s a  ronda de la comunicacion 28050 madrid spain
# 575                                 total s a  2  place jean millier paris france
# 571                                 total s a  2  place jean millier paris france
#
#      jaccard_sim
# 632          1.0
# 2            1.0
# 664          0.9
# 35           0.9
# 194          0.8
# 704          0.8
# 98           0.7
# 241          0.7
# 96           0.6
# 686          0.6
# 659          0.5
# 234          0.5
# 291          0.4
# 706          0.4
# 176          0.3
# 518          0.3
# 305          0.2
# 306          0.2
# 575          0.1
# 571          0.1
