# %% [markdown]
# # PyMinHash example notebook

# %% [markdown]
# This example notebook shows how to use PyMinHash to find matches of strings.

# %% [markdown]
# First, import Pandas and fix some settings.

# %%
# %config Completer.use_jedi = False

import pandas as pd

pd.set_option('display.max_columns', 100)
pd.set_option('display.max_row', 500)
pd.set_option('display.max_colwidth', 200)

# %% [markdown]
# PyMinHash comes with a toy dataset containing various name and address combinations of Stoxx50 companies.

# %%
from pyminhash.datasets import load_data
df = load_data()
df.head()
# Out:
#                                                            name
# 0                 adidas ag adi dassler strasse 1 91074 germany
# 1          adidas ag adi dassler strasse 1 91074 herzogenaurach
# 2  adidas ag adi dassler strasse 1 91074 herzogenaurach germany
# 3                          airbus se 2333 cs leiden netherlands
# 4                                 airbus se 2333 cs netherlands

# %% [markdown]
# We're going to match various representations that belong to the same company. For this, we import create a `MinHash` object and tell it to use 10 hash tables. More hash tables means more accurate Jaccard similarity calculation but also requires more time and memory.

# %%
from pyminhash.pyminhash import MinHash
myHasher = MinHash(n_hash_tables=10)

# %% [markdown]
# The `fit_predict` method needs the dataframe and the name of the column to which minhashing should be applied. The result is a dataframe containing all pairs that have a non-zero Jaccard similarity:

# %%
result = myHasher.fit_predict(df, 'name')
result.head()
# Out:
#       row_number_1  row_number_2  \
# 33              31            33
# 611             13            14
# 1330            77            78
# 93              49            50
# 750             42            43
#
#                                                                name_1  \
# 33         bayerische motoren werke aktiengesellschaft munich germany
# 611   anheuser busch inbev sa nv brouwerijplein 1 3000 leuven belgium
# 1330               koninklijke ahold delhaize n v   provincialeweg 11
# 93            deutsche post ag platz der deutschen post 53113 germany
# 750                  danone s a  15  rue du helder 75439 paris france
#
#                                                                          name_2  \
# 33    bayerische motoren werke aktiengesellschaft petuelring 130 munich germany
# 611                  anheuser busch inbev sa nv brouwerijplein 1 leuven belgium
# 1330             koninklijke ahold delhaize n v   provincialeweg 11 netherlands
# 93                       deutsche post ag platz der deutschen post bonn germany
# 750                                  danone s a  15  rue du helder paris france
#
#       jaccard_sim
# 33            1.0
# 611           1.0
# 1330          1.0
# 93            1.0
# 750           1.0

# %% [markdown]
# As one can see below, for a Jaccard similarity of 1.0, all words in the shortest string appear in the longest string. For lower Jaccard similarity values, the match is less than perfect. Note that Jaccard similarity has granularity of `1/n_hash_tables`, in this example 0.1. For more accurate Jaccard similarity use a larger value of `n_hash_tables`.

# %%
result.groupby('jaccard_sim').head(2)
# Out:
#       row_number_1  row_number_2  \
# 33              31            33
# 611             13            14
# 546            126           127
# 359             10            11
# 305             79            81
# 356             31            32
# 567             75           129
# 292              7             8
# 570             84           129
# 593            126           129
# 685             98           103
# 14              28            29
# 954             36           100
# 910             43            98
# 1068           103           106
# 527             85           127
# 765             44            60
# 1015           103           104
# 1328            76            77
# 1323            76            80
#
#                                                                name_1  \
# 33         bayerische motoren werke aktiengesellschaft munich germany
# 611   anheuser busch inbev sa nv brouwerijplein 1 3000 leuven belgium
# 546               vinci sa 1  cours ferdinand de lesseps 92851 france
# 359      amadeus it group  s a  salvador de madariaga  1 28027 madrid
# 305                    koninklijke philips n v  amstelplein 2 1096 bc
# 356        bayerische motoren werke aktiengesellschaft munich germany
# 567                     kering sa 40 rue de sevres 75007 paris france
# 292                       allianz se koniginstrasse 28 munich germany
# 570                                   l air liquide s a  paris france
# 593               vinci sa 1  cours ferdinand de lesseps 92851 france
# 685                                    orange s a  75015 paris france
# 14                                           bayer aktiengesellschaft
# 954                                              bnp paribas sa paris
# 910                        danone s a  15  rue du helder paris france
# 1068                                           safran sa paris france
# 527                   l oreal s a  41  rue martre 92117 clichy france
# 765                                           danone s a  75439 paris
# 1015                                           safran sa paris france
# 1328     koninklijke ahold delhaize n v   1506 ma zaandam netherlands
# 1323     koninklijke ahold delhaize n v   1506 ma zaandam netherlands
#
#                                                                          name_2  \
# 33    bayerische motoren werke aktiengesellschaft petuelring 130 munich germany
# 611                  anheuser busch inbev sa nv brouwerijplein 1 leuven belgium
# 546                               vinci sa 1  cours ferdinand de lesseps france
# 359          amadeus it group  s a  salvador de madariaga  1 28027 madrid spain
# 305                  koninklijke philips n v  amstelplein 2 1096 bc netherlands
# 356     bayerische motoren werke aktiengesellschaft petuelring 130 80788 munich
# 567                        vivendi sa 42 avenue de friedland 75380 paris france
# 292                                                   allianz se munich germany
# 570                        vivendi sa 42 avenue de friedland 75380 paris france
# 593                        vivendi sa 42 avenue de friedland 75380 paris france
# 685                                                      safran sa paris france
# 14                            bayer aktiengesellschaft 51368 leverkusen germany
# 954                                                           orange s a  paris
# 910                                              orange s a  75015 paris france
# 1068                                                        sanofi 75008 france
# 527                               vinci sa 1  cours ferdinand de lesseps france
# 765                    essilorluxottica 1 6 rue paul cezanne 75008 paris france
# 1015                                      sanofi 54  rue la boetie 75008 france
# 1328                         koninklijke ahold delhaize n v   provincialeweg 11
# 1323                   koninklijke philips n v  amstelplein 2 1096 bc amsterdam
#
#       jaccard_sim
# 33            1.0
# 611           1.0
# 546           0.9
# 359           0.9
# 305           0.8
# 356           0.8
# 567           0.7
# 292           0.7
# 570           0.6
# 593           0.6
# 685           0.5
# 14            0.5
# 954           0.4
# 910           0.4
# 1068          0.3
# 527           0.3
# 765           0.2
# 1015          0.2
# 1328          0.1
# 1323          0.1
