# %% [markdown]
# # Tutorial

# %% [markdown]
# This tutorial shows how to use PyMinHash to find matches of strings.

# %% [markdown]
# First, import Pandas and fix some settings.

# %%
# %config Completer.use_jedi = False

import pandas as pd

pd.set_option('display.max_columns', 100)
pd.set_option('display.max_row', 500)
pd.set_option('display.max_colwidth', 200)

# %% [markdown]
# PyMinHash comes with a toy dataset containing various name and address combinations of Stoxx50 companies.

# %%
from pyminhash.datasets import load_data
df = load_data()
df.head()
# Out:
#                                                            name
# 0                 adidas ag adi dassler strasse 1 91074 germany
# 1          adidas ag adi dassler strasse 1 91074 herzogenaurach
# 2  adidas ag adi dassler strasse 1 91074 herzogenaurach germany
# 3                          airbus se 2333 cs leiden netherlands
# 4                                 airbus se 2333 cs netherlands

# %% [markdown]
# We're going to match various representations that belong to the same company. For this, we import create a `MinHash` object and tell it to use 10 hash tables. More hash tables means more accurate Jaccard similarity calculation but also requires more time and memory.

# %%
from pyminhash.pyminhash import MinHash
myHasher = MinHash(n_hash_tables=10)

# %% [markdown]
# The `fit_predict` method needs the dataframe and the name of the column to which minhashing should be applied. The result is a dataframe containing all pairs that have a non-zero Jaccard similarity:

# %%
result = myHasher.fit_predict(df, 'name')
result.head()
# Out:
#       row_number_1  row_number_2  \
# 406             67            68
# 1343            77            78
# 928             60            61
# 595            126           127
# 322             31            33
#
#                                                                                           name_1  \
# 406   industria de diseno textil  s a  avenida de la diputacion s n arteixo 15143 a coruna spain
# 1343                                          koninklijke ahold delhaize n v   provincialeweg 11
# 928                                     essilorluxottica 1 6 rue paul cezanne 75008 paris france
# 595                                          vinci sa 1  cours ferdinand de lesseps 92851 france
# 322                                   bayerische motoren werke aktiengesellschaft munich germany
#
#                                                                                     name_2  \
# 406   industria de diseno textil  s a  avenida de la diputacion s n arteixo a coruna spain
# 1343                        koninklijke ahold delhaize n v   provincialeweg 11 netherlands
# 928                                     essilorluxottica 1 6 rue paul cezanne paris france
# 595                                          vinci sa 1  cours ferdinand de lesseps france
# 322              bayerische motoren werke aktiengesellschaft petuelring 130 munich germany
#
#       jaccard_sim
# 406           1.0
# 1343          1.0
# 928           1.0
# 595           0.9
# 322           0.9

# %% [markdown]
# As one can see below, for a Jaccard similarity of 1.0, all words in the shortest string appear in the longest string. For lower Jaccard similarity values, the match is less than perfect. Note that Jaccard similarity has granularity of `1/n_hash_tables`, in this example 0.1. For more accurate Jaccard similarity use a larger value of `n_hash_tables`.

# %%
result.groupby('jaccard_sim').head(2)
# Out:
#       row_number_1  row_number_2  \
# 406             67            68
# 1343            77            78
# 595            126           127
# 322             31            33
# 146             62            64
# 709             24            25
# 724             12            14
# 777             19           101
# 852             98           103
# 861             18           130
# 1031            83            98
# 653             19           129
# 940             19            83
# 240             52           131
# 470             56            99
# 938             17            83
# 1279           103           125
# 111             50            62
# 1136            60           112
# 350              9            15
#
#                                                                                           name_1  \
# 406   industria de diseno textil  s a  avenida de la diputacion s n arteixo 15143 a coruna spain
# 1343                                          koninklijke ahold delhaize n v   provincialeweg 11
# 595                                          vinci sa 1  cours ferdinand de lesseps 92851 france
# 322                                   bayerische motoren werke aktiengesellschaft munich germany
# 146         fresenius se   co  kgaa else kroner strasse 1 61352 bad homburg vor der hohe germany
# 709                                                           banco santander  s a  28660 madrid
# 724                                               anheuser busch inbev sa nv 3000 leuven belgium
# 777                                                                    axa sa 75008 paris france
# 852                                                               orange s a  75015 paris france
# 861                                                                           axa sa 75008 paris
# 1031                                                       l air liquide s a  75007 paris france
# 653                                                                    axa sa 75008 paris france
# 940                                                                    axa sa 75008 paris france
# 240                                                            deutsche telekom ag 53113 germany
# 470                                           engie sa 1  place samuel de champlain 92400 france
# 938                                                axa sa 25  avenue matignon 75008 paris france
# 1279                                                                      safran sa paris france
# 111                                       deutsche post ag platz der deutschen post bonn germany
# 1136                                    essilorluxottica 1 6 rue paul cezanne 75008 paris france
# 350                                        amadeus it group  s a  salvador de madariaga  1 28027
#
#                                                                                     name_2  \
# 406   industria de diseno textil  s a  avenida de la diputacion s n arteixo a coruna spain
# 1343                        koninklijke ahold delhaize n v   provincialeweg 11 netherlands
# 595                                          vinci sa 1  cours ferdinand de lesseps france
# 322              bayerische motoren werke aktiengesellschaft petuelring 130 munich germany
# 146         fresenius se   co  kgaa else kroner strasse 1 bad homburg vor der hohe germany
# 709                                               banco santander  s a  28660 madrid spain
# 724                             anheuser busch inbev sa nv brouwerijplein 1 leuven belgium
# 777                           safran sa 2  boulevard du general martial valin paris france
# 852                                                                 safran sa paris france
# 861                                                                 vivendi sa 75380 paris
# 1031                                                        orange s a  75015 paris france
# 653                                   vivendi sa 42 avenue de friedland 75380 paris france
# 940                                                  l air liquide s a  75007 paris france
# 240                                                            volkswagen ag 38440 germany
# 470                               orange s a  78  rue olivier de serres 75015 paris france
# 938                                                  l air liquide s a  75007 paris france
# 1279                                                                      total s a  paris
# 111   fresenius se   co  kgaa else kroner strasse 1 61352 bad homburg vor der hohe germany
# 1136                                                  schneider electric s e  92500 france
# 350                            asml holding n v  de run 6501 5504 dr veldhoven netherlands
#
#       jaccard_sim
# 406           1.0
# 1343          1.0
# 595           0.9
# 322           0.9
# 146           0.8
# 709           0.8
# 724           0.7
# 777           0.7
# 852           0.6
# 861           0.6
# 1031          0.5
# 653           0.5
# 940           0.4
# 240           0.4
# 470           0.3
# 938           0.3
# 1279          0.2
# 111           0.2
# 1136          0.1
# 350           0.1
